# %%
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import PAIRWISE_DISTANCE_FUNCTIONS
import numpy as np
import matplotlib.pyplot as plt

plt.ion()
# %matplotlib widget

# %%
OUTPUT_DIM = 2

# %%
def load_embbed(pickle_path: str) -> tuple:
    data = np.load(pickle_path, allow_pickle=True).tolist()
    file_refs = data['fnames']
    embeds    = data['embeddings']
    labels    = data['labels']
    classes   = data['classes']

    embeds = np.vstack(embeds)
    labels = np.vstack(labels)

    return file_refs, embeds, labels, classes

def plot_embed(data, labels):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.scatter(data[:,0], data[:,1], data[:,2], c=labels)
    plt.show()

# %%
tsne = TSNE(n_components=3, init='pca', method='exact', perplexity=40, verbose=1, metric='cosine')

# %% [markdown]
# # UNI

# %%
file_refs, embeds, labels, classes = load_embbed("extracted-embeddings/UNI.npy")
embeds.shape, labels.shape
# Out:
# ((7582, 1024), (7582, 1))

# %%
output = tsne.fit_transform(embeds)
output.shape
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7582
# [t-SNE] Computed conditional probabilities for sample 2000 / 7582
# [t-SNE] Computed conditional probabilities for sample 3000 / 7582
# [t-SNE] Computed conditional probabilities for sample 4000 / 7582
# [t-SNE] Computed conditional probabilities for sample 5000 / 7582
# [t-SNE] Computed conditional probabilities for sample 6000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7582 / 7582
# [t-SNE] Mean sigma: 0.085305
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.287642

# %%
plot_embed(output, labels)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # UNI2

# %%
file_refs, embeds, labels, classes = load_embbed("extracted-embeddings/UNI2.npy")
embeds.shape, labels.shape
# Out:
# ((7582, 1536), (7582, 1))

# %%
output = tsne.fit_transform(embeds)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7582 samples in 0.005s...
# [t-SNE] Computed neighbors for 7582 samples in 0.932s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7582
# [t-SNE] Computed conditional probabilities for sample 2000 / 7582
# [t-SNE] Computed conditional probabilities for sample 3000 / 7582
# [t-SNE] Computed conditional probabilities for sample 4000 / 7582
# [t-SNE] Computed conditional probabilities for sample 5000 / 7582
# [t-SNE] Computed conditional probabilities for sample 6000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7582 / 7582
# [t-SNE] Mean sigma: 3.463386
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.201736
# [t-SNE] KL divergence after 1000 iterations: 1.215221

# %%
output.shape
# Out:
# (7582, 3)

# %%
plot_embed(output, labels)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Phikon

# %%
file_refs, embeds, labels, classes = load_embbed("extracted-embeddings/Phikon.npy")
embeds.shape, labels.shape
# Out:
# ((7582, 768), (7582, 1))

# %%
output = tsne.fit_transform(embeds)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7582 samples in 0.002s...
# [t-SNE] Computed neighbors for 7582 samples in 0.409s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7582
# [t-SNE] Computed conditional probabilities for sample 2000 / 7582
# [t-SNE] Computed conditional probabilities for sample 3000 / 7582
# [t-SNE] Computed conditional probabilities for sample 4000 / 7582
# [t-SNE] Computed conditional probabilities for sample 5000 / 7582
# [t-SNE] Computed conditional probabilities for sample 6000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7582 / 7582
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.939579
# [t-SNE] KL divergence after 1000 iterations: 0.681451

# %%
output.shape
# Out:
# (7582, 3)

# %%
plot_embed(output, labels)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # PhikonV2

# %%
file_refs, embeds, labels, classes = load_embbed("extracted-embeddings/PhikonV2.npy")
embeds.shape, labels.shape
# Out:
# ((7582, 1024), (7582, 1))

# %%
output = tsne.fit_transform(embeds)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7582 samples in 0.004s...
# [t-SNE] Computed neighbors for 7582 samples in 0.529s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7582
# [t-SNE] Computed conditional probabilities for sample 2000 / 7582
# [t-SNE] Computed conditional probabilities for sample 3000 / 7582
# [t-SNE] Computed conditional probabilities for sample 4000 / 7582
# [t-SNE] Computed conditional probabilities for sample 5000 / 7582
# [t-SNE] Computed conditional probabilities for sample 6000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7000 / 7582
# [t-SNE] Computed conditional probabilities for sample 7582 / 7582
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.063354
# [t-SNE] KL divergence after 1000 iterations: 0.731435

# %%
output.shape
# Out:
# (7582, 3)

# %%
plot_embed(output, labels)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
